# %% [markdown]
# <a href="https://colab.research.google.com/github/monindew/study.../blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({
    'id' : [1, 2, 3],
    'customer_id' : [1, 2, 3],
    'customer_name' : ['Robert', 'Peter', 'Dave'],
})

# %%
df2 = pd.DataFrame({
    'id' : [1, 2, 4],
    'order_id' : [100, 200, 300],
    'order_data' : ['2021-01-21', '2021-02-03', '2020-10-01']
})

# %%
df1
# Out:
#    id  customer_id customer_name
# 0   1            1        Robert
# 1   2            2         Peter
# 2   3            3          Dave

# %%
df2
# Out:
#    id  order_id  order_data
# 0   1       100  2021-01-21
# 1   2       200  2021-02-03
# 2   4       300  2020-10-01

# %%
pd.concat([df1, df2])
# Out:
#    id  customer_id customer_name  order_id  order_data
# 0   1          1.0        Robert       NaN         NaN
# 1   2          2.0         Peter       NaN         NaN
# 2   3          3.0          Dave       NaN         NaN
# 0   1          NaN           NaN     100.0  2021-01-21
# 1   2          NaN           NaN     200.0  2021-02-03
# 2   4          NaN           NaN     300.0  2020-10-01

# %%
pd.concat([df1, df2], axis=1)
# Out:
#    id  customer_id customer_name  id  order_id  order_data
# 0   1            1        Robert   1       100  2021-01-21
# 1   2            2         Peter   2       200  2021-02-03
# 2   3            3          Dave   4       300  2020-10-01

# %%
pd.merge(df1, df2)
# Out:
#    id  customer_id customer_name  order_id  order_data
# 0   1            1        Robert       100  2021-01-21
# 1   2            2         Peter       200  2021-02-03

# %%
pd.merge(df1, df2, on='id')
# Out:
#    id  customer_id customer_name  order_id  order_data
# 0   1            1        Robert       100  2021-01-21
# 1   2            2         Peter       200  2021-02-03

# %%
pd.merge(df1, df2, on='id', how='outer')
# Out:
#    id  customer_id customer_name  order_id  order_data
# 0   1          1.0        Robert     100.0  2021-01-21
# 1   2          2.0         Peter     200.0  2021-02-03
# 2   3          3.0          Dave       NaN         NaN
# 3   4          NaN           NaN     300.0  2020-10-01

# %%
pd.merge(df1, df2, on='id', how='left')
# Out:
#    id  customer_id customer_name  order_id  order_data
# 0   1            1        Robert     100.0  2021-01-21
# 1   2            2         Peter     200.0  2021-02-03
# 2   3            3          Dave       NaN         NaN

# %%
pd.merge(df1, df2, on='id', how='right')
# Out:
#    id  customer_id customer_name  order_id  order_data
# 0   1          1.0        Robert       100  2021-01-21
# 1   2          2.0         Peter       200  2021-02-03
# 2   4          NaN           NaN       300  2020-10-01

# %%
df1 = df1.set_index('id')
df1
# Out:
#     customer_id customer_name
# id
# 1             1        Robert
# 2             2         Peter
# 3             3          Dave

# %%
df2 = df2.set_index('id')
df2
# Out:
#     order_id  order_data
# id
# 1        100  2021-01-21
# 2        200  2021-02-03
# 4        300  2020-10-01

# %%
pd.merge(df1, df2, left_index=True, right_index=True)
# Out:
#     customer_id customer_name  order_id  order_data
# id
# 1             1        Robert       100  2021-01-21
# 2             2         Peter       200  2021-02-03

# %%
pd.merge(df1, df2, how='outer', left_index=True, right_index=True)
# Out:
#     customer_id customer_name  order_id  order_data
# id
# 1           1.0        Robert     100.0  2021-01-21
# 2           2.0         Peter     200.0  2021-02-03
# 3           3.0          Dave       NaN         NaN
# 4           NaN           NaN     300.0  2020-10-01
