# %% [markdown]
# <a href="https://colab.research.google.com/github/monindew/study.../blob/main/20240904_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.DataFrame({
    "A" : [1, 2, 3, 4, 5, 6],
    "C" : [1, 2, 3, 4, 5, 100]
})
df
# Out:
#    A    C
# 0  1    1
# 1  2    2
# 2  3    3
# 3  4    4
# 4  5    5
# 5  6  100

# %%
df.describe()
# Out:
#               A           C
# count  6.000000    6.000000
# mean   3.500000   19.166667
# std    1.870829   39.625329
# min    1.000000    1.000000
# 25%    2.250000    2.250000
# 50%    3.500000    3.500000
# 75%    4.750000    4.750000
# max    6.000000  100.000000
