# %% [markdown]
# <a href="https://colab.research.google.com/github/monindew/study.../blob/main/20240904.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install chart-studio --upgrade
# !pip install cufflinks --upgrade

# %%
import chart_studio.plotly as py
import cufflinks as cf
cf.go_offline(connected=True)
import plotly.io as pio
pio.renderers.default = "colab"
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import numpy as np
np.random.rand(5)
# Out:
# array([0.97069089, 0.92825501, 0.15563127, 0.57858809, 0.38317797])

# %%
np.random.rand(5, 2)
# Out:
# array([[0.70636296, 0.65019712],
#        [0.45046316, 0.86205866],
#        [0.82353366, 0.80470198],
#        [0.57778304, 0.39726028],
#        [0.15306002, 0.01921201]])

# %%
import pandas as pd

df = pd.DataFrame(np.random.rand(10, 2), columns=['A', 'B'])
df.head()
# Out:
#           A         B
# 0  0.874709  0.696449
# 1  0.314913  0.129522
# 2  0.065143  0.760276
# 3  0.839501  0.007144
# 4  0.275875  0.723340

# %%
cf.help()
# Out:
# Use 'cufflinks.help(figure)' to see the list of available parameters for the given figure.
# Use 'DataFrame.iplot(kind=figure)' to plot the respective figure
# Figures:
# 	bar
# 	box
# 	bubble
# 	bubble3d
# 	candle
# 	choroplet
# 	distplot
# 	heatmap
# 	histogram
# 	ohlc
# 	pie
# 	ratio
# 	scatter
# 	scatter3d
# 	scattergeo
# 	spread
# 	surface
# 	violin

# %%
df.iplot(kind='bar')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e05ae2e3-dc41-4beb-a9ab-c2cd7e1bedb1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.plot(kind='bar')
# Out:
# <Axes: >

# %%
cf.help('bar')
# Out:
# BAR
# Bar Chart
# Supports categories and horizontal bar charts
#
#
# Parameters:
# ...
#     bargap : float
#         Sets the gap between bars
#         	[0,1)
#     bargroupgap : float
#         Sets the gap between groups
#         	[0,1)
#     barmode : string
#         Bar mode
#         	group
#         	stack
#         	overlay
#     categories : string
#         Name of the column that contains the categories
#     orientation : string
#         Sets the orientation of the bars.
#         	h
#         	v
#     sortbars : bool
#         Sort bars in descending order
#
#
#     colors : dict, list or string
#         Trace color
#         	string : applies to all traces
#         	list : applies to each trace in the order specified
#         	dict : {column:value} for each column in the dataframe
#         values
#         	colorname : see cufflinks.colors.cnames
#         	hex : '#ffffff'
#         	rgb : 'rgb(23,50,23)'
#         	rgba : 'rgba(23,50,23,.5)
# ...

# %%
df.iplot(kind='bar', barmode='stack')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f1b6725e-4076-4d34-8270-676fab12fd7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df['A'].iplot(kind='bar')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="615ef631-a77e-4fc1-9096-840a38ee7d6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bar', barmode='stack', orientation='h')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f8ded7a0-70ac-4e64-bd36-20a38833c15f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df['A'].iplot(kind='bar', orientation='h')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5dec7728-4a37-4f5e-b0e6-42b5436afe21" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
cf.help('scatter')
# Out:
# SCATTER
# Scatter plot
# 2D chart based in an x and y axis.
# Can be a line chart (default) or a set of scatter points (markers)
#
#
# Parameters:
# ...
#     bestfit : bool or list
#         Displays a best fit line
#         If list, then a best fit line will be generated
#         for each trace key in the list
#     bestfit_colors : dict or list
#         Sets the color for each best fit line
#         	{key:color} to set the color for each trace
#         	[color1, color2...] to set the colors in the specified order
#     categories : string
#         Name of the column that contains the categories
#     connectgaps : bool
#         If True, then empty values are connected
#     dash : string, list or dict
#         Line style
#         	string : applies to all traces
#         	list : applies to each trace in the order specified
#         	dict : {column:value} for each column in the dataframe
#         values    :
#         	solid
#         	dash
#         	dashdot
#         	dot
# ...

# %%
df.iplot(kind='scatter')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0f8b572a-ca28-4576-800e-7515c170a3a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter', mode='lines+markers')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a17cc484-9d4e-4c42-a790-9fdf9a069587" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter', fill=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4ac3ffb5-8f83-4582-a5f0-3f520be35046" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter',
         fill=True,
         xTitle='x title',
         yTitle='y title',
         title='title')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="13e4027e-8e12-48d0-84d0-25b87c1f7af1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
themes = cf.getThemes()
themes
# Out:
# ['ggplot', 'pearl', 'solar', 'space', 'white', 'polar', 'henanigans']

# %%
for theme in themes:
  df.iplot(kind='scatter',
           theme=theme,
           fill=True,
           title=theme)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9e5db5f8-afcf-43b5-9017-a0f16eea51d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
layout = {
    'title' :
        {
            'text' : 'TTT',
            'font' :  {
                'size' : 20,
                'family' : 'consolas',
                'color' : 'blue'
            } ,
            'x' : 0.5,
            'y' : 0.85

        }
}
df.iplot(kind='scatter', layout=layout)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="50f6951b-fafc-4ffc-9ffe-f956f1b391eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="046475a7-0edb-4072-8467-e04a73ecf997" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = "colab"

# %%
fig = go.Figure()
fig.add_trace(
    go.Scatter(
        x=[1, 2, 3], y=[1, 2, 3]
    )
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dir(go)
# Out:
# ['AngularAxis',
#  'Annotation',
#  'Annotations',
#  'Bar',
#  'Barpolar',
#  'Box',
#  'Candlestick',
#  'Carpet',
#  'Choropleth',
#  'Choroplethmapbox',
#  'ColorBar',
#  'Cone',
#  'Contour',
#  'Contourcarpet',
#  'Contours',
#  'Data',
#  'Densitymapbox',
#  'ErrorX',
#  'ErrorY',
#  'ErrorZ',
#  'Figure',
#  'FigureWidget',
#  'Font',
#  'Frame',
#  'Frames',
#  'Funnel',
#  'Funnelarea',
#  'Heatmap',
#  'Heatmapgl',
#  'Histogram',
#  'Histogram2d',
#  'Histogram2dContour',
#  'Histogram2dcontour',
#  'Icicle',
#  'Image',
#  'Indicator',
#  'Isosurface',
#  'Layout',
#  'Legend',
#  'Line',
#  'Margin',
#  'Marker',
#  'Mesh3d',
#  'Ohlc',
#  'Parcats',
#  'Parcoords',
#  'Pie',
#  'Pointcloud',
#  'RadialAxis',
#  'Sankey',
#  'Scatter',
#  'Scatter3d',
#  'Scattercarpet',
#  'Scattergeo',
#  'Scattergl',
#  'Scattermapbox',
#  'Scatterpolar',
#  'Scatterpolargl',
#  'Scattersmith',
#  'Scatterternary',
#  'Scene',
#  'Splom',
#  'Stream',
#  'Streamtube',
#  'Sunburst',
# ...

# %%
fig = go.Figure()
fig.add_trace(
    go.Scatter(
        x=df.index, y=df['A']
    )
)
fig.update_layout(
    {
        "title" :{
            "text" : "Graph with go.Scatter",
            "font" : {
                "size" : 15
            }
        },
        "showlegend" : True,
        "xaxis" : {
            "title" : "random number"
        },
        "yaxis" : {
            "title" : "A"
        }
    }
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = go.Figure()
fig.add_trace(
    go.Scatter(
        x=df.index, y=df["B"], mode="lines", name="B"
    )
)
fig.add_trace(
    go.Scatter(
        x=df.index, y=df["A"], mode="lines+markers+text", name="A", text=df.index, textposition="top center"
    )
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = go.Figure()
fig.add_trace(
    go.Bar(
        x=df.index, y=df["B"], name="B", text=df["B"], textposition="auto", texttemplate="%{y:.2f}"
    )
)
fig.add_trace(
    go.Bar(
        x=df.index, y=df["A"], name="A", text=df["A"], textposition="auto", texttemplate="%{y:.2f}"
    )
)

fig.update_layout(
    {
        "title" : {
            "text" : "Graph with <b>go.Bar</b>",
            "x" : 0.5,
            "y" : 0.9,
            "font" : {
                "size" : 20
            }
        },
        "showlegend" : True,
        "xaxis" : {
            "title" : "random number",
            "showticklabels":True,
            "dtick" : 1
        },
        "yaxis" : {
            "title" : "A"
        },
        "autosize" : False,
        "width" : 800,
        "height" : 800

    }
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
