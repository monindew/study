# %% [markdown]
# <a href="https://colab.research.google.com/github/monindew/study.../blob/main/visual_Flouish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
doc = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-22-2020.csv")

# %%
doc.head()
# Out:
#   Province/State  Country/Region      Last Update  Confirmed  Deaths  \
# 0          Anhui  Mainland China  1/22/2020 17:00        1.0     NaN
# 1        Beijing  Mainland China  1/22/2020 17:00       14.0     NaN
# 2      Chongqing  Mainland China  1/22/2020 17:00        6.0     NaN
# 3         Fujian  Mainland China  1/22/2020 17:00        1.0     NaN
# 4          Gansu  Mainland China  1/22/2020 17:00        NaN     NaN
#
#    Recovered
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
try:
  doc = doc[[ "Province_State", "Country_Region", "Confirmed"]]
except:
  doc = doc[[ 'Province/State', 'Country/Region', 'Confirmed']]
  doc.columns = [ 'Province_State', 'Country_Region', "Confirmed"]

doc.head()
# Out:
#   Province_State  Country_Region  Confirmed
# 0          Anhui  Mainland China        1.0
# 1        Beijing  Mainland China       14.0
# 2      Chongqing  Mainland China        6.0
# 3         Fujian  Mainland China        1.0
# 4          Gansu  Mainland China        NaN

# %%
doc = doc.dropna(subset=["Confirmed"])
doc = doc.astype({'Confirmed' : 'int64'})
doc.head()
# Out:
#   Province_State  Country_Region  Confirmed
# 0          Anhui  Mainland China          1
# 1        Beijing  Mainland China         14
# 2      Chongqing  Mainland China          6
# 3         Fujian  Mainland China          1
# 5      Guangdong  Mainland China         26

# %%
country_info = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/UID_ISO_FIPS_LookUp_Table.csv")
country_info.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2 Province_State Country_Region       Lat  \
# 0    4   AF  AFG    4.0   NaN    NaN            NaN    Afghanistan  33.93911
# 1    8   AL  ALB    8.0   NaN    NaN            NaN        Albania  41.15330
# 2   10   AQ  ATA   10.0   NaN    NaN            NaN     Antarctica -71.94990
# 3   12   DZ  DZA   12.0   NaN    NaN            NaN        Algeria  28.03390
# 4   20   AD  AND   20.0   NaN    NaN            NaN        Andorra  42.50630
#
#        Long_ Combined_Key  Population
# 0  67.709953  Afghanistan  38928341.0
# 1  20.168300      Albania   2877800.0
# 2  23.347000   Antarctica         NaN
# 3   1.659600      Algeria  43851043.0
# 4   1.521800      Andorra     77265.0

# %%
test_df = pd.merge(doc, country_info, how='left', on='Country_Region')
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3993 entries, 0 to 3992
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Province_State_x  3932 non-null   object
#  1   Country_Region    3993 non-null   object
#  2   Confirmed         3993 non-null   int64
#  3   UID               3967 non-null   float64
#  4   iso2              3965 non-null   object
#  5   iso3              3965 non-null   object
#  6   code3             3965 non-null   float64
#  7   FIPS              3384 non-null   float64
#  8   Admin2            3343 non-null   object
#  9   Province_State_y  3927 non-null   object
#  10  Lat               3820 non-null   float64
#  11  Long_             3820 non-null   float64
#  12  Combined_Key      3967 non-null   object
#  13  Population        3817 non-null   float64
# dtypes: float64(6), int64(1), object(7)
# memory usage: 436.9+ KB

# %%
test_df.isnull().sum()
# Out:
# Province_State_x     61
# Country_Region        0
# Confirmed             0
# UID                  26
# iso2                 28
# iso3                 28
# code3                28
# FIPS                609
# Admin2              650
# Province_State_y     66
# Lat                 173
# Long_               173
# Combined_Key         26
# Population          176
# dtype: int64

# %%
nan_rows = test_df[test_df['iso2'].isnull()]
nan_rows.head()
# Out:
#   Province_State_x  Country_Region  Confirmed  UID iso2 iso3  code3  FIPS  \
# 0            Anhui  Mainland China          1  NaN  NaN  NaN    NaN   NaN
# 1          Beijing  Mainland China         14  NaN  NaN  NaN    NaN   NaN
# 2        Chongqing  Mainland China          6  NaN  NaN  NaN    NaN   NaN
# 3           Fujian  Mainland China          1  NaN  NaN  NaN    NaN   NaN
# 4        Guangdong  Mainland China         26  NaN  NaN  NaN    NaN   NaN
#
#   Admin2 Province_State_y  Lat  Long_ Combined_Key  Population
# 0    NaN              NaN  NaN    NaN          NaN         NaN
# 1    NaN              NaN  NaN    NaN          NaN         NaN
# 2    NaN              NaN  NaN    NaN          NaN         NaN
# 3    NaN              NaN  NaN    NaN          NaN         NaN
# 4    NaN              NaN  NaN    NaN          NaN         NaN

# %%
import json

with open('country_convert.json', 'r', encoding='utf-8-sig') as json_file:
  json_data = json.load(json_file)
  print(json_data.keys())
# Out:
# dict_keys(['Mainland China', 'Macau', 'South Korea', 'Aruba', ' Azerbaijan', 'Bahamas, The', 'Cape Verde', 'Cayman Islands', 'Channel Islands', 'Curacao', 'Czech Republic', 'East Timor', 'Faroe Islands', 'French Guiana', 'Gambia, The', 'Gibraltar', 'Greenland', 'Guadeloupe', 'Guam', 'Guernsey', 'Hong Kong', 'Hong Kong SAR', 'Iran (Islamic Republic of)', 'Ivory Coast', 'Jersey', 'Macao SAR', 'Martinique', 'Mayotte', 'North Ireland', 'Palestine', 'Puerto Rico', 'Republic of Ireland', 'Republic of Korea', 'Republic of Moldova', 'Republic of the Congo', 'Reunion', 'Russian Federation', 'Saint Barthelemy', 'Saint Martin', 'St. Martin', 'Taipei and environs', 'The Bahamas', 'The Gambia', 'UK', 'Vatican City', 'Viet Nam', 'occupied Palestinian territory', 'Taiwan*', 'Malawi', 'South Sudan', 'Western Sahara', 'Namibia'])

# %%
df = pd.DataFrame({
    '영어' : [60, 70],
    '수학' : [100, 50]
}, index = ['Dave', 'David'])
df
# Out:
#        영어   수학
# Dave   60  100
# David  70   50

# %%
def func(df_data):
  print(type(df_data))
  print(df_data.index)
  print(df_data.values)
  return df_data

# %%
df_func = df.apply(func, axis=0)
# Out:
# <class 'pandas.core.series.Series'>
# Index(['Dave', 'David'], dtype='object')
# [60 70]
# <class 'pandas.core.series.Series'>
# Index(['Dave', 'David'], dtype='object')
# [100  50]

# %%
df_func = df.apply(func, axis=1)
# Out:
# <class 'pandas.core.series.Series'>
# Index(['영어', '수학'], dtype='object')
# [ 60 100]
# <class 'pandas.core.series.Series'>
# Index(['영어', '수학'], dtype='object')
# [70 50]

# %%
def func(df_data):
  df_data['영어'] = 80
  return df_data

# %%
df_func = df.apply(func, axis=1)

# %%
df_func
# Out:
#        영어   수학
# Dave   80  100
# David  80   50

# %%
doc = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-22-2020.csv", encoding='utf-8-sig')
try:
  doc = doc[[ "Province_State", "Country_Region", "Confirmed"]]
except:
  doc = doc[[ "Province/State", "Country/Region", "Confirmed"]]
  doc.columns = [ "Province_State", "Country_Region", "Confirmed"]

doc = doc.dropna(subset=["Confirmed"])
doc = doc.astype({ "Confirmed" : 'int64'})
doc.head()
# Out:
#   Province_State  Country_Region  Confirmed
# 0          Anhui  Mainland China          1
# 1        Beijing  Mainland China         14
# 2      Chongqing  Mainland China          6
# 3         Fujian  Mainland China          1
# 5      Guangdong  Mainland China         26

# %%
import json

with open('country_convert.json', 'r', encoding='utf-8-sig') as json_file:
  json_data = json.load(json_file)
  print(json_data.keys())
# Out:
# dict_keys(['Mainland China', 'Macau', 'South Korea', 'Aruba', ' Azerbaijan', 'Bahamas, The', 'Cape Verde', 'Cayman Islands', 'Channel Islands', 'Curacao', 'Czech Republic', 'East Timor', 'Faroe Islands', 'French Guiana', 'Gambia, The', 'Gibraltar', 'Greenland', 'Guadeloupe', 'Guam', 'Guernsey', 'Hong Kong', 'Hong Kong SAR', 'Iran (Islamic Republic of)', 'Ivory Coast', 'Jersey', 'Macao SAR', 'Martinique', 'Mayotte', 'North Ireland', 'Palestine', 'Puerto Rico', 'Republic of Ireland', 'Republic of Korea', 'Republic of Moldova', 'Republic of the Congo', 'Reunion', 'Russian Federation', 'Saint Barthelemy', 'Saint Martin', 'St. Martin', 'Taipei and environs', 'The Bahamas', 'The Gambia', 'UK', 'Vatican City', 'Viet Nam', 'occupied Palestinian territory', 'Taiwan*', 'Malawi', 'South Sudan', 'Western Sahara', 'Namibia'])

# %%
def func(row):
  if row["Country_Region"] in json_data:
    row["Country_Region"] = json_data[row["Country_Region"]]
  return row

# %%
doc = doc.apply(func, axis=1)
doc.head()
# Out:
#   Province_State Country_Region  Confirmed
# 0          Anhui          China          1
# 1        Beijing          China         14
# 2      Chongqing          China          6
# 3         Fujian          China          1
# 5      Guangdong          China         26

# %%
data = '01-22-2020.csv'
date_column = data.split(".")[0].lstrip('0').replace('-', '/')
date_column
# Out:
# '1/22/2020'

# %%
doc.columns
# Out:
# Index(['Province_State', 'Country_Region', 'Confirmed'], dtype='object')

# %%
doc.columns = [ 'Province_State', 'Country_Region', date_column]
doc.columns
# Out:
# Index(['Province_State', 'Country_Region', '1/22/2020'], dtype='object')

# %%
doc.head()
# Out:
#   Province_State Country_Region  1/22/2020
# 0          Anhui          China          1
# 1        Beijing          China         14
# 2      Chongqing          China          6
# 3         Fujian          China          1
# 5      Guangdong          China         26

# %%
df = pd.DataFrame({
    '성별' : ['남', '남', '남'],
    '이름' : ['David', 'Dave', "Dave"],
    '수학' : [100, 50, 80],
    '국어' : [80, 70, 50]
})
df
# Out:
#   성별     이름   수학  국어
# 0  남  David  100  80
# 1  남   Dave   50  70
# 2  남   Dave   80  50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   성별      3 non-null      object
#  1   이름      3 non-null      object
#  2   수학      3 non-null      int64
#  3   국어      3 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 224.0+ bytes

# %%
df.groupby('이름')[['수학', '국어']].mean()
# Out:
#           수학    국어
# 이름
# Dave    65.0  60.0
# David  100.0  80.0

# %%
df.groupby('이름')[['수학', '국어']].sum()
# Out:
#         수학   국어
# 이름
# Dave   130  120
# David  100   80

# %%
doc = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-22-2020.csv", encoding='utf-8-sig')
try:
  doc = doc[[ "Province_State", "Country_Region", "Confirmed"]]
except:
  doc = doc[[ "Province/State", "Country/Region", "Confirmed"]]
  doc.columns = [ "Province_State", "Country_Region", "Confirmed"]

doc = doc.dropna(subset=["Confirmed"])
doc = doc.astype({ "Confirmed" : 'int64'})
doc.head()
# Out:
#   Province_State  Country_Region  Confirmed
# 0          Anhui  Mainland China          1
# 1        Beijing  Mainland China         14
# 2      Chongqing  Mainland China          6
# 3         Fujian  Mainland China          1
# 5      Guangdong  Mainland China         26

# %%
doc.groupby('Country_Region')['Confirmed'].sum()
# Out:
# Country_Region
# Antarctica                0
# Japan                     2
# Kiribati                  0
# Korea, North              0
# Macau                     1
# Mainland China          547
# Malaysia                  0
# Nauru                     0
# New Zealand               0
# Palau                     0
# South Korea               1
# Summer Olympics 2020      0
# Taiwan                    1
# Thailand                  4
# Tonga                     0
# Tuvalu                    0
# US                        1
# Ukraine                   0
# United Kingdom            0
# Winter Olympics 2022      0
# Name: Confirmed, dtype: int64
